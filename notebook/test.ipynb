# %%
from pathlib import Path
import os

# %%
path = Path(r"D:\KrishNaik\LLMOOPs-Projects\Project-1-Document-Portal\notebook\test.ipynb")

# %%
path
# Out:
# WindowsPath('D:/KrishNaik/LLMOOPs-Projects/Project-1-Document-Portal/notebook/test.ipynb')

# %%
Path(os.getenv("DATA_STORAGE_PATH", ""))
# Out:
# WindowsPath('.')
